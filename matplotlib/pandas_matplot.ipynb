# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("sample_Datasets.xlsx")

# %%
df.head()
# Out:
#   Student_ID Program  Attendance   GPA
# 0      ST001    BSIT          95  1.75
# 1      ST002    BSBA          88  2.25
# 2      ST003    BSIT          91  1.60
# 3      ST004    BSCS         120  1.80
# 4      ST005    BSHM          82  2.10

# %%
df.tail()
# Out:
#    Student_ID                    Program  Attendance  GPA
# 6       ST007                       BSIT          94  1.9
# 7       ST008                       BSCS          90  NaN
# 8       ST009                       BSHM          86  2.0
# 9       ST010  Bachelor of Science in IT          93  1.7
# 10      ST010                       BSIT          93  1.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  11 non-null     object
#  1   Program     11 non-null     object
#  2   Attendance  11 non-null     int64
#  3   GPA         10 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 484.0+ bytes

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Program       0
# Attendance    0
# GPA           1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Program"].unique()
# Out:
# array(['BSIT', 'BSBA', 'BSCS', 'BSHM', 'Bachelor of Science in IT'],
#       dtype=object)

# %%
df["Program"] = df["Program"].replace({
    "Bachelor of Science in IT": "BSIT"
})

df["Program"].unique()
# Out:
# array(['BSIT', 'BSBA', 'BSCS', 'BSHM'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated(subset=["Student_ID"], keep=False)]
# Out:
#    Student_ID Program  Attendance  GPA
# 9       ST010    BSIT          93  1.7
# 10      ST010    BSIT          93  1.7

# %%
df = df.drop_duplicates(subset=["Student_ID"])

display(df)
# Out:
#   Student_ID Program  Attendance   GPA
# 0      ST001    BSIT          95  1.75
# 1      ST002    BSBA          88  2.25
# 2      ST003    BSIT          91  1.60
# 3      ST004    BSCS         120  1.80
# 4      ST005    BSHM          82  2.10
# 5      ST006    BSBA          -5  2.30
# 6      ST007    BSIT          94  1.90
# 7      ST008    BSCS          90   NaN
# 8      ST009    BSHM          86  2.00
# 9      ST010    BSIT          93  1.70

# %%
df = df.dropna(subset=["GPA"])

display(df)
# Out:
#   Student_ID Program  Attendance   GPA
# 0      ST001    BSIT          95  1.75
# 1      ST002    BSBA          88  2.25
# 2      ST003    BSIT          91  1.60
# 3      ST004    BSCS         120  1.80
# 4      ST005    BSHM          82  2.10
# 5      ST006    BSBA          -5  2.30
# 6      ST007    BSIT          94  1.90
# 8      ST009    BSHM          86  2.00
# 9      ST010    BSIT          93  1.70

# %%
df["Attendance"] = df["Attendance"].clip(0,100)
display(df)
# Out:
#   Student_ID Program  Attendance   GPA
# 0      ST001    BSIT          95  1.75
# 1      ST002    BSBA          88  2.25
# 2      ST003    BSIT          91  1.60
# 3      ST004    BSCS         100  1.80
# 4      ST005    BSHM          82  2.10
# 5      ST006    BSBA           0  2.30
# 6      ST007    BSIT          94  1.90
# 8      ST009    BSHM          86  2.00
# 9      ST010    BSIT          93  1.70

# %%
programStudents = df["Program"].value_counts()

plt.bar(programStudents.index, programStudents.values, color="maroon")

plt.title("Number of Students by Program")
plt.xlabel("Students")
plt.ylabel("Programs")

plt.show()
