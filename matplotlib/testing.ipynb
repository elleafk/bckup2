# %%
import matplotlib.pyplot as plt

program = ["BSIT", "BSCRIM", "BSED", "BSHM"]
students = [342,120,92,204]

plt.bar(program, students)

plt.title("Number of Students Per Program")
plt.xlabel("Courses")
plt.ylabel("Number of students")
plt.show()
